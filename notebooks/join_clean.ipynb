# %% [markdown]
# # Joining and cleaning data for UCLA EDA Final Project

# %% [markdown]
# ### Importing Libraries and Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Read in the data
housing = pd.read_csv('data/housing.csv')
schools = pd.read_csv('data/schools.csv')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   neighborhood  683 non-null    object
#  1   beds          683 non-null    int64
#  2   baths         683 non-null    float64
#  3   sqft          681 non-null    float64
#  4   lotsize       663 non-null    float64
#  5   year          683 non-null    int64
#  6   type          683 non-null    object
#  7   levels        683 non-null    object
#  8   cooling       676 non-null    object
#  9   heating       676 non-null    object
#  10  fireplace     677 non-null    object
#  11  elementary    683 non-null    object
#  12  middle        683 non-null    object
#  13  high          683 non-null    object
#  14  soldprice     683 non-null    int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 80.2+ KB

# %%
schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   school  52 non-null     object
#  1   size    52 non-null     int64
#  2   rating  52 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# ### Data Joining

# %%
# Merge the data
# Use list to join each school type to the housing data
s_types = ["Elementary", "Middle", "High"]

# Create temporary dataframes for each school type and merge with housing dataframe
# Add size and rating columns to the housing dataframe for each school type
for s_type in s_types:

    size_col_name = (s_type + "_size").lower()
    rating_col_name = (s_type + "_rating").lower()

    tdf = schools[schools['school'].str.contains(s_type)]
    housing = housing.merge(tdf, left_on=s_type.lower(), right_on='school', how='left')

    housing = housing.rename(columns={'size': size_col_name, 'rating': rating_col_name})

# Remove the redundant school columns
housing.drop(columns=['school_x', 'school_y', 'school'], inplace=True)

# %%
cols = ['neighborhood', 'beds', 'baths', 'sqft', 'lotsize', 'year', 'type',
       'levels', 'cooling', 'heating', 'fireplace', 'soldprice', 'elementary',
       'elementary_size','elementary_rating', 'middle','middle_size','middle_rating',
       'high','high_size', 'high_rating']

housing = housing[cols]

# %%
housing.columns
# Out:
# Index(['neighborhood', 'beds', 'baths', 'sqft', 'lotsize', 'year', 'type',
#        'levels', 'cooling', 'heating', 'fireplace', 'soldprice', 'elementary',
#        'elementary_size', 'elementary_rating', 'middle', 'middle_size',
#        'middle_rating', 'high', 'high_size', 'high_rating'],
#       dtype='object')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 683 entries, 0 to 682
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   neighborhood       683 non-null    object
#  1   beds               683 non-null    int64
#  2   baths              683 non-null    float64
#  3   sqft               681 non-null    float64
#  4   lotsize            663 non-null    float64
#  5   year               683 non-null    int64
#  6   type               683 non-null    object
#  7   levels             683 non-null    object
#  8   cooling            676 non-null    object
#  9   heating            676 non-null    object
#  10  fireplace          677 non-null    object
#  11  soldprice          683 non-null    int64
#  12  elementary         683 non-null    object
#  13  elementary_size    683 non-null    int64
#  14  elementary_rating  683 non-null    int64
#  15  middle             683 non-null    object
#  16  middle_size        683 non-null    int64
#  17  middle_rating      683 non-null    int64
#  18  high               683 non-null    object
#  19  high_size          683 non-null    int64
#  20  high_rating        683 non-null    int64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 117.4+ KB

# %%
housing.describe()
# Out:
#              beds       baths         sqft     lotsize         year  \
# count  683.000000  683.000000   681.000000  663.000000   683.000000
# mean     4.937042    2.001464  2127.562408    0.288869  1977.461201
# std     38.121012    1.392269  1069.311206    0.184496    30.280016
# min      1.000000    1.000000   536.000000    0.070000  1495.000000
# 25%      3.000000    1.000000  1349.000000    0.160000  1961.000000
# 50%      4.000000    1.500000  1955.000000    0.240000  1978.000000
# 75%      4.000000    2.500000  2676.000000    0.360000  1997.000000
# max    999.000000   25.000000  5265.000000    1.300000  2111.000000
#
#           soldprice  elementary_size  elementary_rating  middle_size  \
# count  6.830000e+02       683.000000         683.000000   683.000000
# mean   1.244857e+06       742.825769           5.746706   693.265007
# std    3.761917e+05       102.282215           2.404535   120.233272
# min    6.640000e+02       600.000000           1.000000   500.000000
# 25%    9.745000e+05       700.000000           4.000000   600.000000
# 50%    1.267000e+06       750.000000           6.000000   700.000000
# 75%    1.548000e+06       800.000000           8.000000   800.000000
# max    2.393000e+06       900.000000          10.000000   900.000000
#
#        middle_rating    high_size  high_rating
# count     683.000000   683.000000   683.000000
# mean        6.178624   967.423133     5.926794
# std         1.948083   153.084918     2.920837
# min         2.000000   750.000000     1.000000
# 25%         5.000000   850.000000     4.000000
# 50%         7.000000  1000.000000     6.000000
# 75%         8.000000  1100.000000     8.000000
# max         9.000000  1250.000000    10.000000

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# The goal of data cleaning is to handle missing values, remove outliers, and handle any other data issues that may arise. The data cleaning process is iterative, so it is important to keep track of the changes made to the data.

# %%
# Change some columns to categorical.
housing['cooling'] = pd.Categorical(housing['cooling'], categories=['Yes', 'No'], ordered=True)
housing['heating'] = pd.Categorical(housing['heating'], categories=['Yes', 'No'], ordered=True)
housing['fireplace'] = pd.Categorical(housing['fireplace'], categories=['Yes', 'No'], ordered=True)
housing['type'] = pd.Categorical(housing['type'], ordered=True)

# %%
nbhs = housing.groupby('neighborhood')['soldprice'].mean().sort_values(ascending=False).index.to_list()

housing['neighborhood'] = pd.Categorical(housing['neighborhood'], categories=nbhs, ordered=True)

# %%
housing.to_csv('data/joined.csv', index=False)

# %% [markdown]
# #### Missing Values

# %% [markdown]
# For the first iteration of analysis, we will drop all rows with missing values in any column. In the future, we may want to impute missing values where possible and appropriate.

# %%
housing.dropna(inplace=True)
print(housing.shape)
# Out:
# (645, 21)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 645 entries, 0 to 682
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   neighborhood       645 non-null    category
#  1   beds               645 non-null    int64
#  2   baths              645 non-null    float64
#  3   sqft               645 non-null    float64
#  4   lotsize            645 non-null    float64
#  5   year               645 non-null    int64
#  6   type               645 non-null    category
#  7   levels             645 non-null    object
#  8   cooling            645 non-null    category
#  9   heating            645 non-null    category
#  10  fireplace          645 non-null    category
#  11  soldprice          645 non-null    int64
#  12  elementary         645 non-null    object
#  13  elementary_size    645 non-null    int64
#  14  elementary_rating  645 non-null    int64
#  15  middle             645 non-null    object
#  16  middle_size        645 non-null    int64
#  17  middle_rating      645 non-null    int64
#  18  high               645 non-null    object
#  19  high_size          645 non-null    int64
#  20  high_rating        645 non-null    int64
# dtypes: category(5), float64(3), int64(9), object(4)
# memory usage: 89.7+ KB

# %%
housing.describe().style.text_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_8b4f0_row0_col0, #T_8b4f0_row0_col1, #T_8b4f0_row0_col3, #T_8b4f0_row0_col7, #T_8b4f0_row0_col9, #T_8b4f0_row0_col11, #T_8b4f0_row7_col2, #T_8b4f0_row7_col4, #T_8b4f0_row7_col5, #T_8b4f0_row7_col6, #T_8b4f0_row7_col8, #T_8b4f0_row7_col10 {
#   color: #023858;
# }
# #T_8b4f0_row0_col2 {
#   color: #fbf4f9;
# }
# #T_8b4f0_row0_col4 {
#   color: #c1cae2;
# }
# #T_8b4f0_row0_col5, #T_8b4f0_row1_col0, #T_8b4f0_row1_col1, #T_8b4f0_row1_col3, #T_8b4f0_row2_col0, #T_8b4f0_row2_col1, #T_8b4f0_row2_col3, #T_8b4f0_row2_col4, #T_8b4f0_row2_col6, #T_8b4f0_row2_col7, #T_8b4f0_row2_col8, #T_8b4f0_row2_col9, #T_8b4f0_row2_col10, #T_8b4f0_row2_col11, #T_8b4f0_row3_col0, #T_8b4f0_row3_col1, #T_8b4f0_row3_col2, #T_8b4f0_row3_col3, #T_8b4f0_row3_col5, #T_8b4f0_row3_col7, #T_8b4f0_row3_col9, #T_8b4f0_row3_col11, #T_8b4f0_row4_col0, #T_8b4f0_row4_col1, #T_8b4f0_row4_col3, #T_8b4f0_row5_col1, #T_8b4f0_row5_col3, #T_8b4f0_row6_col1, #T_8b4f0_row6_col3, #T_8b4f0_row7_col3 {
#   color: #fff7fb;
# }
# #T_8b4f0_row0_col6 {
#   color: #2081b9;
# }
# #T_8b4f0_row0_col8 {
#   color: #2383ba;
# }
# #T_8b4f0_row0_col10 {
#   color: #89b1d4;
# }
# #T_8b4f0_row1_col2 {
#   color: #afc1dd;
# }
# #T_8b4f0_row1_col4, #T_8b4f0_row5_col4 {
#   color: #034973;
# }
# #T_8b4f0_row1_col5 {
#   color: #69a5cc;
# }
# #T_8b4f0_row1_col6 {
#   color: #0566a0;
# }
# #T_8b4f0_row1_col7, #T_8b4f0_row1_col9, #T_8b4f0_row1_col11, #T_8b4f0_row4_col7, #T_8b4f0_row4_col9, #T_8b4f0_row4_col11, #T_8b4f0_row5_col0, #T_8b4f0_row5_col7, #T_8b4f0_row5_col11, #T_8b4f0_row6_col0, #T_8b4f0_row7_col0 {
#   color: #fef6fb;
# }
# #T_8b4f0_row1_col8 {
#   color: #0a73b2;
# }
# #T_8b4f0_row1_col10 {
#   color: #0872b1;
# }
# #T_8b4f0_row2_col2 {
#   color: #eee8f3;
# }
# #T_8b4f0_row2_col5 {
#   color: #e5e1ef;
# }
# #T_8b4f0_row3_col4 {
#   color: #167bb6;
# }
# #T_8b4f0_row3_col6 {
#   color: #3790c0;
# }
# #T_8b4f0_row3_col8 {
#   color: #79abd0;
# }
# #T_8b4f0_row3_col10 {
#   color: #5ea0ca;
# }
# #T_8b4f0_row4_col2 {
#   color: #e0dded;
# }
# #T_8b4f0_row4_col4 {
#   color: #034b76;
# }
# #T_8b4f0_row4_col5 {
#   color: #9ab8d8;
# }
# #T_8b4f0_row4_col6 {
#   color: #0570b0;
# }
# #T_8b4f0_row4_col8 {
#   color: #3b92c1;
# }
# #T_8b4f0_row4_col10 {
#   color: #328dbf;
# }
# #T_8b4f0_row5_col2 {
#   color: #bcc7e1;
# }
# #T_8b4f0_row5_col5 {
#   color: #65a3cb;
# }
# #T_8b4f0_row5_col6 {
#   color: #05659f;
# }
# #T_8b4f0_row5_col8 {
#   color: #0771b1;
# }
# #T_8b4f0_row5_col9, #T_8b4f0_row6_col7, #T_8b4f0_row6_col9, #T_8b4f0_row6_col11, #T_8b4f0_row7_col9 {
#   color: #fef6fa;
# }
# #T_8b4f0_row5_col10 {
#   color: #056caa;
# }
# #T_8b4f0_row6_col2 {
#   color: #80aed2;
# }
# #T_8b4f0_row6_col4 {
#   color: #03476f;
# }
# #T_8b4f0_row6_col5 {
#   color: #2c89bd;
# }
# #T_8b4f0_row6_col6, #T_8b4f0_row6_col8 {
#   color: #045a8d;
# }
# #T_8b4f0_row6_col10 {
#   color: #045c90;
# }
# #T_8b4f0_row7_col1 {
#   color: #faf2f8;
# }
# #T_8b4f0_row7_col7, #T_8b4f0_row7_col11 {
#   color: #fdf5fa;
# }
# </style>
# <table id="T_8b4f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b4f0_level0_col0" class="col_heading level0 col0" >beds</th>
#       <th id="T_8b4f0_level0_col1" class="col_heading level0 col1" >baths</th>
#       <th id="T_8b4f0_level0_col2" class="col_heading level0 col2" >sqft</th>
#       <th id="T_8b4f0_level0_col3" class="col_heading level0 col3" >lotsize</th>
#       <th id="T_8b4f0_level0_col4" class="col_heading level0 col4" >year</th>
#       <th id="T_8b4f0_level0_col5" class="col_heading level0 col5" >soldprice</th>
#       <th id="T_8b4f0_level0_col6" class="col_heading level0 col6" >elementary_size</th>
#       <th id="T_8b4f0_level0_col7" class="col_heading level0 col7" >elementary_rating</th>
#       <th id="T_8b4f0_level0_col8" class="col_heading level0 col8" >middle_size</th>
#       <th id="T_8b4f0_level0_col9" class="col_heading level0 col9" >middle_rating</th>
#       <th id="T_8b4f0_level0_col10" class="col_heading level0 col10" >high_size</th>
#       <th id="T_8b4f0_level0_col11" class="col_heading level0 col11" >high_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b4f0_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8b4f0_row0_col0" class="data row0 col0" >645.000000</td>
#       <td id="T_8b4f0_row0_col1" class="data row0 col1" >645.000000</td>
#       <td id="T_8b4f0_row0_col2" class="data row0 col2" >645.000000</td>
#       <td id="T_8b4f0_row0_col3" class="data row0 col3" >645.000000</td>
#       <td id="T_8b4f0_row0_col4" class="data row0 col4" >645.000000</td>
#       <td id="T_8b4f0_row0_col5" class="data row0 col5" >645.000000</td>
#       <td id="T_8b4f0_row0_col6" class="data row0 col6" >645.000000</td>
#       <td id="T_8b4f0_row0_col7" class="data row0 col7" >645.000000</td>
#       <td id="T_8b4f0_row0_col8" class="data row0 col8" >645.000000</td>
#       <td id="T_8b4f0_row0_col9" class="data row0 col9" >645.000000</td>
#       <td id="T_8b4f0_row0_col10" class="data row0 col10" >645.000000</td>
#       <td id="T_8b4f0_row0_col11" class="data row0 col11" >645.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b4f0_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_8b4f0_row1_col0" class="data row1 col0" >3.499225</td>
#       <td id="T_8b4f0_row1_col1" class="data row1 col1" >2.024031</td>
#       <td id="T_8b4f0_row1_col2" class="data row1 col2" >2137.982946</td>
#       <td id="T_8b4f0_row1_col3" class="data row1 col3" >0.291147</td>
#       <td id="T_8b4f0_row1_col4" class="data row1 col4" >1976.965891</td>
#       <td id="T_8b4f0_row1_col5" class="data row1 col5" >1245957.618605</td>
#       <td id="T_8b4f0_row1_col6" class="data row1 col6" >744.806202</td>
#       <td id="T_8b4f0_row1_col7" class="data row1 col7" >5.736434</td>
#       <td id="T_8b4f0_row1_col8" class="data row1 col8" >693.798450</td>
#       <td id="T_8b4f0_row1_col9" class="data row1 col9" >6.151938</td>
#       <td id="T_8b4f0_row1_col10" class="data row1 col10" >965.038760</td>
#       <td id="T_8b4f0_row1_col11" class="data row1 col11" >5.916279</td>
#     </tr>
#     <tr>
#       <th id="T_8b4f0_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_8b4f0_row2_col0" class="data row2 col0" >1.468748</td>
#       <td id="T_8b4f0_row2_col1" class="data row2 col1" >1.411123</td>
#       <td id="T_8b4f0_row2_col2" class="data row2 col2" >1067.260761</td>
#       <td id="T_8b4f0_row2_col3" class="data row2 col3" >0.185822</td>
#       <td id="T_8b4f0_row2_col4" class="data row2 col4" >30.760931</td>
#       <td id="T_8b4f0_row2_col5" class="data row2 col5" >376943.202541</td>
#       <td id="T_8b4f0_row2_col6" class="data row2 col6" >102.037479</td>
#       <td id="T_8b4f0_row2_col7" class="data row2 col7" >2.413470</td>
#       <td id="T_8b4f0_row2_col8" class="data row2 col8" >119.913231</td>
#       <td id="T_8b4f0_row2_col9" class="data row2 col9" >1.954891</td>
#       <td id="T_8b4f0_row2_col10" class="data row2 col10" >153.398985</td>
#       <td id="T_8b4f0_row2_col11" class="data row2 col11" >2.930213</td>
#     </tr>
#     <tr>
#       <th id="T_8b4f0_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_8b4f0_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_8b4f0_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_8b4f0_row3_col2" class="data row3 col2" >536.000000</td>
#       <td id="T_8b4f0_row3_col3" class="data row3 col3" >0.070000</td>
#       <td id="T_8b4f0_row3_col4" class="data row3 col4" >1495.000000</td>
#       <td id="T_8b4f0_row3_col5" class="data row3 col5" >664.000000</td>
#       <td id="T_8b4f0_row3_col6" class="data row3 col6" >600.000000</td>
#       <td id="T_8b4f0_row3_col7" class="data row3 col7" >1.000000</td>
#       <td id="T_8b4f0_row3_col8" class="data row3 col8" >500.000000</td>
#       <td id="T_8b4f0_row3_col9" class="data row3 col9" >2.000000</td>
#       <td id="T_8b4f0_row3_col10" class="data row3 col10" >750.000000</td>
#       <td id="T_8b4f0_row3_col11" class="data row3 col11" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b4f0_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_8b4f0_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_8b4f0_row4_col1" class="data row4 col1" >1

# %% [markdown]
# #### Outliers

# %% [markdown]
# The summary statistics show outliers in our data. Below is a list of the columns with outliers:
#
# - `baths` : 1 outlier; max value of 25 (likely 2.5)
# - `year` : 2 outliers; min value of 1495, max value of 2111 (likely 1945, 2011)
# - `soldprice` : 1 outlier; min value of $664 (likely $664,000)
#
# For the first analysis, we will drop all rows with outliers in any column. In the future, we may want to consider imputing the outliers.

# %%
msk_b = housing['baths'] < 25
msk_y1 = housing['year'] > 1495
msk_y2 = housing['year'] < 2111
msk_sp = housing['soldprice'] > 664

select = pd.concat([msk_b, msk_y1, msk_y2, msk_sp], axis=1).all(axis=1)

#select = select.all()
print("Outlier Rows")
housing[~select].style.text_gradient(axis=0, subset=['baths', 'year', 'soldprice'])
# Out:
# Outlier Rows
# <style type="text/css">
# #T_6f9ef_row0_col2 {
#   color: #fcf4fa;
# }
# #T_6f9ef_row0_col5, #T_6f9ef_row2_col2, #T_6f9ef_row2_col11 {
#   color: #023858;
# }
# #T_6f9ef_row0_col11 {
#   color: #03446a;
# }
# #T_6f9ef_row1_col2, #T_6f9ef_row1_col11, #T_6f9ef_row3_col2, #T_6f9ef_row3_col5 {
#   color: #fff7fb;
# }
# #T_6f9ef_row1_col5 {
#   color: #046097;
# }
# #T_6f9ef_row2_col5 {
#   color: #046198;
# }
# #T_6f9ef_row3_col11 {
#   color: #509ac6;
# }
# </style>
# <table id="T_6f9ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f9ef_level0_col0" class="col_heading level0 col0" >neighborhood</th>
#       <th id="T_6f9ef_level0_col1" class="col_heading level0 col1" >beds</th>
#       <th id="T_6f9ef_level0_col2" class="col_heading level0 col2" >baths</th>
#       <th id="T_6f9ef_level0_col3" class="col_heading level0 col3" >sqft</th>
#       <th id="T_6f9ef_level0_col4" class="col_heading level0 col4" >lotsize</th>
#       <th id="T_6f9ef_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_6f9ef_level0_col6" class="col_heading level0 col6" >type</th>
#       <th id="T_6f9ef_level0_col7" class="col_heading level0 col7" >levels</th>
#       <th id="T_6f9ef_level0_col8" class="col_heading level0 col8" >cooling</th>
#       <th id="T_6f9ef_level0_col9" class="col_heading level0 col9" >heating</th>
#       <th id="T_6f9ef_level0_col10" class="col_heading level0 col10" >fireplace</th>
#       <th id="T_6f9ef_level0_col11" class="col_heading level0 col11" >soldprice</th>
#       <th id="T_6f9ef_level0_col12" class="col_heading level0 col12" >elementary</th>
#       <th id="T_6f9ef_level0_col13" class="col_heading level0 col13" >elementary_size</th>
#       <th id="T_6f9ef_level0_col14" class="col_heading level0 col14" >elementary_rating</th>
#       <th id="T_6f9ef_level0_col15" class="col_heading level0 col15" >middle</th>
#       <th id="T_6f9ef_level0_col16" class="col_heading level0 col16" >middle_size</th>
#       <th id="T_6f9ef_level0_col17" class="col_heading level0 col17" >middle_rating</th>
#       <th id="T_6f9ef_level0_col18" class="col_heading level0 col18" >high</th>
#       <th id="T_6f9ef_level0_col19" class="col_heading level0 col19" >high_size</th>
#       <th id="T_6f9ef_level0_col20" class="col_heading level0 col20" >high_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f9ef_level0_row0" class="row_heading level0 row0" >192</th>
#       <td id="T_6f9ef_row0_col0" class="data row0 col0" >Orange</td>
#       <td id="T_6f9ef_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_6f9ef_row0_col2" class="data row0 col2" >1.500000</td>
#       <td id="T_6f9ef_row0_col3" class="data row0 col3" >2822.000000</td>
#       <td id="T_6f9ef_row0_col4" class="data row0 col4" >0.290000</td>
#       <td id="T_6f9ef_row0_col5" class="data row0 col5" >2111</td>
#       <td id="T_6f9ef_row0_col6" class="data row0 col6" >single-family home</td>
#       <td id="T_6f9ef_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_6f9ef_row0_col8" class="data row0 col8" >Yes</td>
#       <td id="T_6f9ef_row0_col9" class="data row0 col9" >No</td>
#       <td id="T_6f9ef_row0_col10" class="data row0 col10" >No</td>
#       <td id="T_6f9ef_row0_col11" class="data row0 col11" >1393000</td>
#       <td id="T_6f9ef_row0_col12" class="data row0 col12" >Leopard Elementary</td>
#       <td id="T_6f9ef_row0_col13" class="data row0 col13" >900</td>
#       <td id="T_6f9ef_row0_col14" class="data row0 col14" >5</td>
#       <td id="T_6f9ef_row0_col15" class="data row0 col15" >Jackal Middle</td>
#       <td id="T_6f9ef_row0_col16" class="data row0 col16" >850</td>
#       <td id="T_6f9ef_row0_col17" class="data row0 col17" >4</td>
#       <td id="T_6f9ef_row0_col18" class="data row0 col18" >Glacier High</td>
#       <td id="T_6f9ef_row0_col19" class="data row0 col19" >1050</td>
#       <td id="T_6f9ef_row0_col20" class="data row0 col20" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6f9ef_level0_row1" class="row_heading level0 row1" >208</th>
#       <td id="T_6f9ef_row1_col0" class="data row1 col0" >Orange</td>
#       <td id="T_6f9ef_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_6f9ef_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_6f9ef_row1_col3" class="data row1 col3" >753.000000</td>
#       <td id="T_6f9ef_row1_col4" class="data row1 col4" >0.130000</td>
#       <td id="T_6f9ef_row1_col5" class="data row1 col5" >2010</td>
#       <td id="T_6f9ef_row1_col6" class="data row1 col6" >condo</td>
#       <td id="T_6f9ef_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_6f9ef_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_6f9ef_row1_col9" class="data row1 col9" >Yes</td>
#       <td id="T_6f9ef_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_6f9ef_row1_col11" class="data row1 col11" >664</td>
#       <td id="T_6f9ef_row1_col12" class="data row1 col12" >Jaguar Elementary</td>
#       <td id="T_6f9ef_row1_col13" class="data row1 col13" >600</td>
#       <td id="T_6f9ef_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_6f9ef_row1_col15" class="data row1 col15" >Fox Middle</td>
#       <td id="T_6f9ef_row1_col16" class="data row1 col16" >550</td>
#       <td id="T_6f9ef_row1_col17" class="data row1 col17" >6</td>
#       <td id="T_6f9ef_row1_col18" class="data row1 col18" >Glacier High</td>
#       <td id="T_6f9ef_row1_col19" class="data row1 col19" >1050</td>
#       <td id="T_6f9ef_row1_col20" class="data row1 col20" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6f9ef_level0_row2" class="row_heading level0 row2" >519</th>
#       <td id="T_6f9ef_row2_col0" class="data row2 col0" >Blue</td>
#       <td id="T_6f9ef_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_6f9ef_row2_col2" class="data row2 col2" >25.000000</td>
#       <td id="T_6f9ef_row2_col3" class="data row2 col3" >2560.000000</td>
#       <td id="T_6f9ef_row2_col4" class="data row2 col4" >0.370000</td>
#       <td id="T_6f9ef_row2_col5" class="data row2 col5" >2009</td>
#       <td id="T_6f9ef_row2_col6" class="data row2 col6" >single-family home</td>
#       <td id="T_6f9ef_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_6f9ef_row2_col8" class="data row2 col8" >No</td>
#       <td id="T_6f9ef_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_6f9ef_row2_col10" class="data row2 col10" >No</td>
#       <td id="T_6f9ef_row2_col11" class="data row2 col11" >1456000</td>
#       <td id="T_6f9ef_row2_col12" class="data row2 col12" >Caracal Elementary</td>
#       <td id="T_6f9ef_row2_col13" class="data row2 col13" >900</td>
#       <td id="T_6f9ef_row2_col14" class="data row2 col14" >9</td>
#       <td id="T_6f9ef_row2_col15" class="data row2 col15" >Epicyon Middle</td>
#       <td id="T_6f9ef_row2_col16" class="data row2 col16" >700</td>
#       <td id="T_6f9ef_row2_col17" class="data row2 col17" >7</td>
#       <td id="T_6f9ef_row2_col18" class="data row2 col18" >Channel High</td>
#       <td id="T_6f9ef_row2_col19" class="data row2 col19" >850</td>
#       <td id="T_6f9ef_row2_col20" class="data row2 col20" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6f9ef_level0_row3" class="row_heading level0 row3" >676</th>
#       <td id="T_6f9ef_row3_col0" class="data row3 col0" >Silver</td>
#       <td id="T_6f9ef_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_6f9ef_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_6f9ef_row3_col3" class="data row3 col3" >824.000000</td>
#       <td id="T_6f9ef_row3_col4" class="data row3 col4" >0.100000</td>
#       <td id="T_6f9ef_row3_col5" class="data row3 col5" >1495</td>
#       <td id="T_6f9ef_row3_col6" class="data row3 col6" >townhouse</td>
#       <td id="T_6f9ef_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_6f9ef_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_6f9ef_row3_col9" class="data row3 col9" >No</td>
#       <td id="T_6f9ef_row3_col10" class="data row3 col10" >No</td>
#       <td id="T_6f9ef_row3_col11" class="data row3 col11" >832000</td>
#       <td id="T_6f9ef_row3_col12" class="data row3 col12" >Ocicat Elementary</td>
#       <td id="T_6f9ef_row3_col13" class="d

# %%
housing = housing[select].reset_index(drop=True)

# %%
housing.describe().style.text_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_15d16_row0_col0, #T_15d16_row0_col1, #T_15d16_row0_col3, #T_15d16_row0_col7, #T_15d16_row0_col9, #T_15d16_row0_col11, #T_15d16_row7_col2, #T_15d16_row7_col4, #T_15d16_row7_col5, #T_15d16_row7_col6, #T_15d16_row7_col8, #T_15d16_row7_col10 {
#   color: #023858;
# }
# #T_15d16_row0_col2 {
#   color: #fcf4fa;
# }
# #T_15d16_row0_col4, #T_15d16_row5_col2 {
#   color: #bcc7e1;
# }
# #T_15d16_row0_col5, #T_15d16_row1_col1, #T_15d16_row1_col3, #T_15d16_row2_col0, #T_15d16_row2_col1, #T_15d16_row2_col3, #T_15d16_row2_col4, #T_15d16_row2_col6, #T_15d16_row2_col7, #T_15d16_row2_col8, #T_15d16_row2_col9, #T_15d16_row2_col10, #T_15d16_row2_col11, #T_15d16_row3_col0, #T_15d16_row3_col1, #T_15d16_row3_col2, #T_15d16_row3_col3, #T_15d16_row3_col7, #T_15d16_row3_col9, #T_15d16_row3_col11, #T_15d16_row4_col0, #T_15d16_row4_col1, #T_15d16_row4_col3, #T_15d16_row5_col1, #T_15d16_row5_col3, #T_15d16_row6_col1, #T_15d16_row6_col3, #T_15d16_row7_col3 {
#   color: #fff7fb;
# }
# #T_15d16_row0_col6 {
#   color: #2383ba;
# }
# #T_15d16_row0_col8 {
#   color: #2484ba;
# }
# #T_15d16_row0_col10 {
#   color: #8bb2d4;
# }
# #T_15d16_row1_col0, #T_15d16_row1_col7, #T_15d16_row1_col9, #T_15d16_row1_col11, #T_15d16_row4_col7, #T_15d16_row4_col9, #T_15d16_row4_col11, #T_15d16_row5_col0, #T_15d16_row6_col0, #T_15d16_row7_col1 {
#   color: #fef6fb;
# }
# #T_15d16_row1_col2 {
#   color: #adc1dd;
# }
# #T_15d16_row1_col4, #T_15d16_row5_col4 {
#   color: #023d60;
# }
# #T_15d16_row1_col5 {
#   color: #69a5cc;
# }
# #T_15d16_row1_col6 {
#   color: #0566a0;
# }
# #T_15d16_row1_col8 {
#   color: #0a73b2;
# }
# #T_15d16_row1_col10 {
#   color: #0872b1;
# }
# #T_15d16_row2_col2 {
#   color: #eee8f3;
# }
# #T_15d16_row2_col5 {
#   color: #e6e2ef;
# }
# #T_15d16_row3_col4 {
#   color: #03476f;
# }
# #T_15d16_row3_col5 {
#   color: #e0deed;
# }
# #T_15d16_row3_col6 {
#   color: #3790c0;
# }
# #T_15d16_row3_col8 {
#   color: #79abd0;
# }
# #T_15d16_row3_col10 {
#   color: #5ea0ca;
# }
# #T_15d16_row4_col2 {
#   color: #e0dded;
# }
# #T_15d16_row4_col4 {
#   color: #023f64;
# }
# #T_15d16_row4_col5 {
#   color: #99b8d8;
# }
# #T_15d16_row4_col6 {
#   color: #0570b0;
# }
# #T_15d16_row4_col8 {
#   color: #3b92c1;
# }
# #T_15d16_row4_col10 {
#   color: #328dbf;
# }
# #T_15d16_row5_col5 {
#   color: #65a3cb;
# }
# #T_15d16_row5_col6 {
#   color: #05659f;
# }
# #T_15d16_row5_col7, #T_15d16_row5_col9, #T_15d16_row5_col11, #T_15d16_row6_col7, #T_15d16_row6_col9, #T_15d16_row6_col11, #T_15d16_row7_col0, #T_15d16_row7_col9 {
#   color: #fef6fa;
# }
# #T_15d16_row5_col8 {
#   color: #0771b1;
# }
# #T_15d16_row5_col10 {
#   color: #056caa;
# }
# #T_15d16_row6_col2 {
#   color: #80aed2;
# }
# #T_15d16_row6_col4 {
#   color: #023a5b;
# }
# #T_15d16_row6_col5 {
#   color: #2c89bd;
# }
# #T_15d16_row6_col6, #T_15d16_row6_col8 {
#   color: #045a8d;
# }
# #T_15d16_row6_col10 {
#   color: #045c90;
# }
# #T_15d16_row7_col7, #T_15d16_row7_col11 {
#   color: #fdf5fa;
# }
# </style>
# <table id="T_15d16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15d16_level0_col0" class="col_heading level0 col0" >beds</th>
#       <th id="T_15d16_level0_col1" class="col_heading level0 col1" >baths</th>
#       <th id="T_15d16_level0_col2" class="col_heading level0 col2" >sqft</th>
#       <th id="T_15d16_level0_col3" class="col_heading level0 col3" >lotsize</th>
#       <th id="T_15d16_level0_col4" class="col_heading level0 col4" >year</th>
#       <th id="T_15d16_level0_col5" class="col_heading level0 col5" >soldprice</th>
#       <th id="T_15d16_level0_col6" class="col_heading level0 col6" >elementary_size</th>
#       <th id="T_15d16_level0_col7" class="col_heading level0 col7" >elementary_rating</th>
#       <th id="T_15d16_level0_col8" class="col_heading level0 col8" >middle_size</th>
#       <th id="T_15d16_level0_col9" class="col_heading level0 col9" >middle_rating</th>
#       <th id="T_15d16_level0_col10" class="col_heading level0 col10" >high_size</th>
#       <th id="T_15d16_level0_col11" class="col_heading level0 col11" >high_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15d16_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_15d16_row0_col0" class="data row0 col0" >641.000000</td>
#       <td id="T_15d16_row0_col1" class="data row0 col1" >641.000000</td>
#       <td id="T_15d16_row0_col2" class="data row0 col2" >641.000000</td>
#       <td id="T_15d16_row0_col3" class="data row0 col3" >641.000000</td>
#       <td id="T_15d16_row0_col4" class="data row0 col4" >641.000000</td>
#       <td id="T_15d16_row0_col5" class="data row0 col5" >641.000000</td>
#       <td id="T_15d16_row0_col6" class="data row0 col6" >641.000000</td>
#       <td id="T_15d16_row0_col7" class="data row0 col7" >641.000000</td>
#       <td id="T_15d16_row0_col8" class="data row0 col8" >641.000000</td>
#       <td id="T_15d16_row0_col9" class="data row0 col9" >641.000000</td>
#       <td id="T_15d16_row0_col10" class="data row0 col10" >641.000000</td>
#       <td id="T_15d16_row0_col11" class="data row0 col11" >641.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15d16_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_15d16_row1_col0" class="data row1 col0" >3.505460</td>
#       <td id="T_15d16_row1_col1" class="data row1 col1" >1.992200</td>
#       <td id="T_15d16_row1_col2" class="data row1 col2" >2140.468019</td>
#       <td id="T_15d16_row1_col3" class="data row1 col3" >0.291576</td>
#       <td id="T_15d16_row1_col4" class="data row1 col4" >1977.407176</td>
#       <td id="T_15d16_row1_col5" class="data row1 col5" >1247989.079563</td>
#       <td id="T_15d16_row1_col6" class="data row1 col6" >744.539782</td>
#       <td id="T_15d16_row1_col7" class="data row1 col7" >5.741030</td>
#       <td id="T_15d16_row1_col8" class="data row1 col8" >694.071763</td>
#       <td id="T_15d16_row1_col9" class="data row1 col9" >6.154446</td>
#       <td id="T_15d16_row1_col10" class="data row1 col10" >964.898596</td>
#       <td id="T_15d16_row1_col11" class="data row1 col11" >5.923557</td>
#     </tr>
#     <tr>
#       <th id="T_15d16_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_15d16_row2_col0" class="data row2 col0" >1.466411</td>
#       <td id="T_15d16_row2_col1" class="data row2 col1" >1.083586</td>
#       <td id="T_15d16_row2_col2" class="data row2 col2" >1067.452178</td>
#       <td id="T_15d16_row2_col3" class="data row2 col3" >0.186113</td>
#       <td id="T_15d16_row2_col4" class="data row2 col4" >23.613976</td>
#       <td id="T_15d16_row2_col5" class="data row2 col5" >374401.599480</td>
#       <td id="T_15d16_row2_col6" class="data row2 col6" >101.826209</td>
#       <td id="T_15d16_row2_col7" class="data row2 col7" >2.411888</td>
#       <td id="T_15d16_row2_col8" class="data row2 col8" >119.748909</td>
#       <td id="T_15d16_row2_col9" class="data row2 col9" >1.958838</td>
#       <td id="T_15d16_row2_col10" class="data row2 col10" >153.730783</td>
#       <td id="T_15d16_row2_col11" class="data row2 col11" >2.931311</td>
#     </tr>
#     <tr>
#       <th id="T_15d16_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_15d16_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_15d16_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_15d16_row3_col2" class="data row3 col2" >536.000000</td>
#       <td id="T_15d16_row3_col3" class="data row3 col3" >0.070000</td>
#       <td id="T_15d16_row3_col4" class="data row3 col4" >1908.000000</td>
#       <td id="T_15d16_row3_col5" class="data row3 col5" >423000.000000</td>
#       <td id="T_15d16_row3_col6" class="data row3 col6" >600.000000</td>
#       <td id="T_15d16_row3_col7" class="data row3 col7" >1.000000</td>
#       <td id="T_15d16_row3_col8" class="data row3 col8" >500.000000</td>
#       <td id="T_15d16_row3_col9" class="data row3 col9" >2.000000</td>
#       <td id="T_15d16_row3_col10" class="data row3 col10" >750.000000</td>
#       <td id="T_15d16_row3_col11" class="data row3 col11" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15d16_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_15d16_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_15d16_row4_col1" class="data row4 col1" >1.000000</td>

# %%
housing.columns
# Out:
# Index(['neighborhood', 'beds', 'baths', 'sqft', 'lotsize', 'year', 'type',
#        'levels', 'cooling', 'heating', 'fireplace', 'soldprice', 'elementary',
#        'elementary_size', 'elementary_rating', 'middle', 'middle_size',
#        'middle_rating', 'high', 'high_size', 'high_rating'],
#       dtype='object')

# %%
cols = ['beds', 'baths', 'sqft', 'lotsize', 'year', 'soldprice']

# %%
housing.loc[:,cols].reset_index(drop=True)
# Out:
#      beds  baths    sqft  lotsize  year  soldprice
# 0       6    4.0  4233.0     0.88  1926    1289000
# 1       1    1.0   748.0     0.11  1985     499000
# 2       3    2.0  2001.0     0.23  1945     573000
# 3       6    3.5  4454.0     0.43  1938    1246000
# 4       4    3.0  2004.0     0.35  1959    1250000
# ..    ...    ...     ...      ...   ...        ...
# 636     3    1.0  1631.0     0.13  1966    1220000
# 637     3    1.0  1714.0     0.13  1967    1622000
# 638     4    2.5  2560.0     0.21  1977    1143000
# 639     4    2.5  2035.0     0.19  1949    1368000
# 640     6    5.0  4260.0     0.33  1977    1619000
#
# [641 rows x 6 columns]

# %%
housing.to_csv('data/cleaned_01.csv', index=False)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   neighborhood       641 non-null    category
#  1   beds               641 non-null    int64
#  2   baths              641 non-null    float64
#  3   sqft               641 non-null    float64
#  4   lotsize            641 non-null    float64
#  5   year               641 non-null    int64
#  6   type               641 non-null    category
#  7   levels             641 non-null    object
#  8   cooling            641 non-null    category
#  9   heating            641 non-null    category
#  10  fireplace          641 non-null    category
#  11  soldprice          641 non-null    int64
#  12  elementary         641 non-null    object
#  13  elementary_size    641 non-null    int64
#  14  elementary_rating  641 non-null    int64
#  15  middle             641 non-null    object
#  16  middle_size        641 non-null    int64
#  17  middle_rating      641 non-null    int64
#  18  high               641 non-null    object
#  19  high_size          641 non-null    int64
#  20  high_rating        641 non-null    int64
# dtypes: category(5), float64(3), int64(9), object(4)
# memory usage: 84.3+ KB

# %% [markdown]
# ### Imputation of Outliers and Mission Values

# %%
data = pd.read_csv('data/joined.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   neighborhood       683 non-null    object
#  1   beds               683 non-null    int64
#  2   baths              683 non-null    float64
#  3   sqft               681 non-null    float64
#  4   lotsize            663 non-null    float64
#  5   year               683 non-null    int64
#  6   type               683 non-null    object
#  7   levels             683 non-null    object
#  8   cooling            676 non-null    object
#  9   heating            676 non-null    object
#  10  fireplace          677 non-null    object
#  11  soldprice          683 non-null    int64
#  12  elementary         683 non-null    object
#  13  elementary_size    683 non-null    int64
#  14  elementary_rating  683 non-null    int64
#  15  middle             683 non-null    object
#  16  middle_size        683 non-null    int64
#  17  middle_rating      683 non-null    int64
#  18  high               683 non-null    object
#  19  high_size          683 non-null    int64
#  20  high_rating        683 non-null    int64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 112.2+ KB

# %% [markdown]
# Below I will impute the missing values of the `lotsize` column by taking the average percent of square footage to lotsize, converting the sqft to acres and multiplying the percent by the acres.

# %%
data['pct_built'] = (data['sqft'] / (data['lotsize'] * 43560)) * 100
data['lotsize'].fillna((data['pct_built'].mean()) * (data['sqft'] / 43560), inplace=True)

# %%
data['lotsize'].describe()
# Out:
# count    683.000000
# mean       0.305549
# std        0.222838
# min        0.070000
# 25%        0.160000
# 50%        0.250000
# 75%        0.370000
# max        2.339692
# Name: lotsize, dtype: float64

# %% [markdown]
# Below the outliers are replaced with the most likely values.

# %%
msk_b = data['baths'] < 25
msk_y1 = data['year'] > 1495
msk_y2 = data['year'] < 2111
msk_sp = data['soldprice'] > 664

data.loc[~msk_b, 'baths'] = 2.5
data.loc[~msk_y1, 'year'] = 1945
data.loc[~msk_y2, 'year'] = 2011
data.loc[~msk_sp, 'soldprice'] = 664000

# %%
select = pd.concat([msk_b, msk_y1, msk_y2, msk_sp], axis=1).all(axis=1)

#select = select.all()
print("Outlier Rows")
data[~select].style.text_gradient(axis=0, subset=['baths', 'year', 'soldprice'])
# Out:
# Outlier Rows
# <style type="text/css">
# #T_cd813_row0_col2 {
#   color: #b4c4df;
# }
# #T_cd813_row0_col5, #T_cd813_row2_col2, #T_cd813_row2_col11 {
#   color: #023858;
# }
# #T_cd813_row0_col11 {
#   color: #034d79;
# }
# #T_cd813_row1_col2, #T_cd813_row1_col11, #T_cd813_row3_col2, #T_cd813_row3_col5 {
#   color: #fff7fb;
# }
# #T_cd813_row1_col5 {
#   color: #023b5d;
# }
# #T_cd813_row2_col5 {
#   color: #023f64;
# }
# #T_cd813_row3_col11 {
#   color: #d9d8ea;
# }
# </style>
# <table id="T_cd813">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd813_level0_col0" class="col_heading level0 col0" >neighborhood</th>
#       <th id="T_cd813_level0_col1" class="col_heading level0 col1" >beds</th>
#       <th id="T_cd813_level0_col2" class="col_heading level0 col2" >baths</th>
#       <th id="T_cd813_level0_col3" class="col_heading level0 col3" >sqft</th>
#       <th id="T_cd813_level0_col4" class="col_heading level0 col4" >lotsize</th>
#       <th id="T_cd813_level0_col5" class="col_heading level0 col5" >year</th>
#       <th id="T_cd813_level0_col6" class="col_heading level0 col6" >type</th>
#       <th id="T_cd813_level0_col7" class="col_heading level0 col7" >levels</th>
#       <th id="T_cd813_level0_col8" class="col_heading level0 col8" >cooling</th>
#       <th id="T_cd813_level0_col9" class="col_heading level0 col9" >heating</th>
#       <th id="T_cd813_level0_col10" class="col_heading level0 col10" >fireplace</th>
#       <th id="T_cd813_level0_col11" class="col_heading level0 col11" >soldprice</th>
#       <th id="T_cd813_level0_col12" class="col_heading level0 col12" >elementary</th>
#       <th id="T_cd813_level0_col13" class="col_heading level0 col13" >elementary_size</th>
#       <th id="T_cd813_level0_col14" class="col_heading level0 col14" >elementary_rating</th>
#       <th id="T_cd813_level0_col15" class="col_heading level0 col15" >middle</th>
#       <th id="T_cd813_level0_col16" class="col_heading level0 col16" >middle_size</th>
#       <th id="T_cd813_level0_col17" class="col_heading level0 col17" >middle_rating</th>
#       <th id="T_cd813_level0_col18" class="col_heading level0 col18" >high</th>
#       <th id="T_cd813_level0_col19" class="col_heading level0 col19" >high_size</th>
#       <th id="T_cd813_level0_col20" class="col_heading level0 col20" >high_rating</th>
#       <th id="T_cd813_level0_col21" class="col_heading level0 col21" >pct_built</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd813_level0_row0" class="row_heading level0 row0" >192</th>
#       <td id="T_cd813_row0_col0" class="data row0 col0" >Orange</td>
#       <td id="T_cd813_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_cd813_row0_col2" class="data row0 col2" >1.500000</td>
#       <td id="T_cd813_row0_col3" class="data row0 col3" >2822.000000</td>
#       <td id="T_cd813_row0_col4" class="data row0 col4" >0.290000</td>
#       <td id="T_cd813_row0_col5" class="data row0 col5" >2011</td>
#       <td id="T_cd813_row0_col6" class="data row0 col6" >single-family home</td>
#       <td id="T_cd813_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_cd813_row0_col8" class="data row0 col8" >Yes</td>
#       <td id="T_cd813_row0_col9" class="data row0 col9" >No</td>
#       <td id="T_cd813_row0_col10" class="data row0 col10" >No</td>
#       <td id="T_cd813_row0_col11" class="data row0 col11" >1393000</td>
#       <td id="T_cd813_row0_col12" class="data row0 col12" >Leopard Elementary</td>
#       <td id="T_cd813_row0_col13" class="data row0 col13" >900</td>
#       <td id="T_cd813_row0_col14" class="data row0 col14" >5</td>
#       <td id="T_cd813_row0_col15" class="data row0 col15" >Jackal Middle</td>
#       <td id="T_cd813_row0_col16" class="data row0 col16" >850</td>
#       <td id="T_cd813_row0_col17" class="data row0 col17" >4</td>
#       <td id="T_cd813_row0_col18" class="data row0 col18" >Glacier High</td>
#       <td id="T_cd813_row0_col19" class="data row0 col19" >1050</td>
#       <td id="T_cd813_row0_col20" class="data row0 col20" >3</td>
#       <td id="T_cd813_row0_col21" class="data row0 col21" >22.339381</td>
#     </tr>
#     <tr>
#       <th id="T_cd813_level0_row1" class="row_heading level0 row1" >208</th>
#       <td id="T_cd813_row1_col0" class="data row1 col0" >Orange</td>
#       <td id="T_cd813_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_cd813_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_cd813_row1_col3" class="data row1 col3" >753.000000</td>
#       <td id="T_cd813_row1_col4" class="data row1 col4" >0.130000</td>
#       <td id="T_cd813_row1_col5" class="data row1 col5" >2010</td>
#       <td id="T_cd813_row1_col6" class="data row1 col6" >condo</td>
#       <td id="T_cd813_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_cd813_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_cd813_row1_col9" class="data row1 col9" >Yes</td>
#       <td id="T_cd813_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_cd813_row1_col11" class="data row1 col11" >664000</td>
#       <td id="T_cd813_row1_col12" class="data row1 col12" >Jaguar Elementary</td>
#       <td id="T_cd813_row1_col13" class="data row1 col13" >600</td>
#       <td id="T_cd813_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_cd813_row1_col15" class="data row1 col15" >Fox Middle</td>
#       <td id="T_cd813_row1_col16" class="data row1 col16" >550</td>
#       <td id="T_cd813_row1_col17" class="data row1 col17" >6</td>
#       <td id="T_cd813_row1_col18" class="data row1 col18" >Glacier High</td>
#       <td id="T_cd813_row1_col19" class="data row1 col19" >1050</td>
#       <td id="T_cd813_row1_col20" class="data row1 col20" >3</td>
#       <td id="T_cd813_row1_col21" class="data row1 col21" >13.297309</td>
#     </tr>
#     <tr>
#       <th id="T_cd813_level0_row2" class="row_heading level0 row2" >519</th>
#       <td id="T_cd813_row2_col0" class="data row2 col0" >Blue</td>
#       <td id="T_cd813_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_cd813_row2_col2" class="data row2 col2" >2.500000</td>
#       <td id="T_cd813_row2_col3" class="data row2 col3" >2560.000000</td>
#       <td id="T_cd813_row2_col4" class="data row2 col4" >0.370000</td>
#       <td id="T_cd813_row2_col5" class="data row2 col5" >2009</td>
#       <td id="T_cd813_row2_col6" class="data row2 col6" >single-family home</td>
#       <td id="T_cd813_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_cd813_row2_col8" class="data row2 col8" >No</td>
#       <td id="T_cd813_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_cd813_row2_col10" class="data row2 col10" >No</td>
#       <td id="T_cd813_row2_col11" class="data row2 col11" >1456000</td>
#       <td id="T_cd813_row2_col12" class="data row2 col12" >Caracal Elementary</td>
#       <td id="T_cd813_row2_col13" class="data row2 col13" >900</td>
#       <td id="T_cd813_row2_col14" class="data row2 col14" >9</td>
#       <td id="T_cd813_row2_col15" class="data row2 col15" >Epicyon Middle</td>
#       <td id="T_cd813_row2_col16" class="data row2 col16" >700</td>
#       <td id="T_cd813_row2_col17" class="data row2 col17" >7</td>
#       <td id="T_cd813_row2_col18" class="data row2 col18" >Channel High</td>
#       <td id="T_cd813_row2_col19" class="data row2 col19" >850</td>
#       <td id="T_cd813_row2_col20" class="data row2 col20" >4</td>
#       <td id="T_cd813_row2_col21" class="data row2 col21" >15.883652</td>
#     </tr>
#     <tr>
#       <th id="T_cd813_level0_row3" class="row_heading level0 row3" >676</th>
#       <td id="T_cd813_row3_col0" class="data row3 col0" >Silver</td>
#       <td id="T_cd813_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_cd813_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_cd813_row3_col3" class="data row3 col3" >824.000000</td>
#       <td id="T_cd813_row3_col4" class="data row3 col4" >0.100000</td>
#       <td id="T_cd813_row3_col5" class="data row3 col5" >1945</td>
#       <td id="T_cd813_row3_col6" class="data row3 col6" >townhouse</td>
#       <td id="T_cd813_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_cd813_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_cd

# %%
data.to_csv('data/cleaned_02.csv', index=False)
